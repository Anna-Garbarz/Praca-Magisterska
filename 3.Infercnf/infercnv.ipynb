# %%
system("apt-get update", intern = TRUE)
system("apt-get install -y jags", intern = TRUE)
# Out:
#  [1] "Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]"
#  [2] "Get:2 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]"
#  [3] "Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]"
#  [4] "Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease"
#  [5] "Get:5 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,017 kB]"
#  [6] "Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]"
#  [7] "Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease"
#  [8] "Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease"
#  [9] "Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,742 kB]"
# [10] "Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]"
# [11] "Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,246 kB]"
# ...

# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
     install.packages("BiocManager")
BiocManager::install("infercnv")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.21 (BiocManager 1.30.26), R 4.5.0 (2025-04-11)
#
# Installing package(s) 'BiocVersion', 'infercnv'
#
# ...

# %%
library(infercnv)

# %%
# create the infercnv object
library(infercnv)
infercnv_obj = CreateInfercnvObject(raw_counts_matrix="/content/1_and_2.matrix",
                                    annotations_file="/content/1_vs_2.annotations.tsv",
                                    delim="\t",
                                    gene_order_file="gene_pos_file.txt",
                                    ref_group_names=c("control"))
# Out:
# INFO [2025-06-10 06:47:45] Parsing matrix: /content/1_and_2.matrix
# INFO [2025-06-10 06:48:50] Parsing gene order file: gene_pos_file.txt
# INFO [2025-06-10 06:48:50] Parsing cell annotations file: /content/1_vs_2.annotations.tsv
# INFO [2025-06-10 06:48:50] ::order_reduce:Start.
# INFO [2025-06-10 06:48:51] .order_reduce(): expr and order match.
# INFO [2025-06-10 06:48:52] ::process_data:order_reduce:Reduction from positional data, new dimensions (r,c) = 36601,5631 Total=52464582 Min=0 Max=5216.
# INFO [2025-06-10 06:48:53] num genes removed taking into account provided gene ordering list: 1280 = 3.49717220840961% removed.
# INFO [2025-06-10 06:48:53] -filtering out cells < 100 or > Inf, removing 0 % of cells
# WARN [2025-06-10 06:48:54] Please use "options(scipen = 100)" before running infercnv if you are using the analysis_mode="subclusters" option or you may encounter an error while the hclust is being generated.
# INFO [2025-06-10 06:48:58] validating infercnv_obj

# %%
# perform infercnv operations to reveal cnv signal
infercnv_obj = infercnv::run(infercnv_obj,
                             cutoff=0.01,  # use 1 for smart-seq, 0.1 for 10x-genomics
                             out_dir="1_vs_2",  # dir is auto-created for storing outputs
                             cluster_by_groups=T,   # cluster
                             denoise=T,
                             plot_steps=F,
                             resume_mode=TRUE,
                             HMM=T,
                             num_threads=5,
                             window_length = 151
                             )
# Out:
# INFO [2025-06-10 06:50:04] ::process_data:Start
# INFO [2025-06-10 06:50:04] Creating output path 1_vs_2
# INFO [2025-06-10 06:50:04] Checking for saved results.
# INFO [2025-06-10 06:50:04]
#
# 	STEP 1: incoming data
#
# INFO [2025-06-10 06:50:30]
#
# 	STEP 02: Removing lowly expressed genes
#
# INFO [2025-06-10 06:50:30] ::above_min_mean_expr_cutoff:Start
# INFO [2025-06-10 06:50:30] Removing 19366 genes from matrix as below mean expr threshold: 0.01
# INFO [2025-06-10 06:50:31] validating infercnv_obj
# INFO [2025-06-10 06:50:31] There are 15955 genes and 5630 cells remaining in the expr matrix.
# INFO [2025-06-10 06:50:35] Removed 1 genes having fewer than 3 min cells per gene = 0.00626763 % genes removed here
# INFO [2025-06-10 06:50:36] validating infercnv_obj
# INFO [2025-06-10 06:50:55]
#
# 	STEP 03: normalization by sequencing depth
#
# INFO [2025-06-10 06:50:55] normalizing counts matrix by depth
# ...

# %%
# create the infercnv object
library(infercnv)
infercnv_obj = CreateInfercnvObject(raw_counts_matrix="/content/1_and_3.matrix",
                                    annotations_file="/content/1_vs_3.annotations.tsv",
                                    delim="\t",
                                    gene_order_file="gene_pos_file.txt",
                                    ref_group_names=c("control"))
# Out:
# INFO [2025-06-10 07:47:52] Parsing matrix: /content/1_and_3.matrix
# INFO [2025-06-10 07:48:40] Parsing gene order file: gene_pos_file.txt
# INFO [2025-06-10 07:48:40] Parsing cell annotations file: /content/1_vs_3.annotations.tsv
# INFO [2025-06-10 07:48:40] ::order_reduce:Start.
# INFO [2025-06-10 07:48:40] .order_reduce(): expr and order match.
# INFO [2025-06-10 07:48:41] ::process_data:order_reduce:Reduction from positional data, new dimensions (r,c) = 36601,5593 Total=51838276 Min=0 Max=15474.
# INFO [2025-06-10 07:48:41] num genes removed taking into account provided gene ordering list: 1280 = 3.49717220840961% removed.
# INFO [2025-06-10 07:48:42] -filtering out cells < 100 or > Inf, removing 0 % of cells
# WARN [2025-06-10 07:48:43] Please use "options(scipen = 100)" before running infercnv if you are using the analysis_mode="subclusters" option or you may encounter an error while the hclust is being generated.
# INFO [2025-06-10 07:48:47] validating infercnv_obj

# %%
# perform infercnv operations to reveal cnv signal
infercnv_obj = infercnv::run(infercnv_obj,
                             cutoff=0.01,  # use 1 for smart-seq, 0.1 for 10x-genomics
                             out_dir="1_vs_3",  # dir is auto-created for storing outputs
                             cluster_by_groups=T,   # cluster
                             denoise=T,
                             plot_steps=F,
                             resume_mode=TRUE,
                             HMM=T,
                             num_threads=5,
                             window_length = 151
                             )
# Out:
# INFO [2025-06-10 07:48:47] ::process_data:Start
# INFO [2025-06-10 07:48:47] Creating output path 1_vs_3
# INFO [2025-06-10 07:48:47] Checking for saved results.
# INFO [2025-06-10 07:48:47]
#
# 	STEP 1: incoming data
#
# INFO [2025-06-10 07:49:12]
#
# 	STEP 02: Removing lowly expressed genes
#
# INFO [2025-06-10 07:49:12] ::above_min_mean_expr_cutoff:Start
# INFO [2025-06-10 07:49:13] Removing 19151 genes from matrix as below mean expr threshold: 0.01
# INFO [2025-06-10 07:49:13] validating infercnv_obj
# INFO [2025-06-10 07:49:13] There are 16170 genes and 5593 cells remaining in the expr matrix.
# INFO [2025-06-10 07:49:17] Removed 3 genes having fewer than 3 min cells per gene = 0.0185529 % genes removed here
# INFO [2025-06-10 07:49:17] validating infercnv_obj
# INFO [2025-06-10 07:49:36]
#
# 	STEP 03: normalization by sequencing depth
#
# INFO [2025-06-10 07:49:36] normalizing counts matrix by depth
# ...

# %%
# create the infercnv object
library(infercnv)
infercnv_obj = CreateInfercnvObject(raw_counts_matrix="/content/1_and_4.matrix",
                                    annotations_file="/content/1_vs_4.annotations.tsv",
                                    delim="\t",
                                    gene_order_file="gene_pos_file.txt",
                                    ref_group_names=c("control"))
# Out:
# INFO [2025-06-10 08:57:45] Parsing matrix: /content/1_and_4.matrix
# INFO [2025-06-10 08:58:52] Parsing gene order file: gene_pos_file.txt
# INFO [2025-06-10 08:58:52] Parsing cell annotations file: /content/1_vs_4.annotations.tsv
# INFO [2025-06-10 08:58:52] ::order_reduce:Start.
# INFO [2025-06-10 08:58:53] .order_reduce(): expr and order match.
# INFO [2025-06-10 08:58:54] ::process_data:order_reduce:Reduction from positional data, new dimensions (r,c) = 36601,7783 Total=91895129 Min=0 Max=9376.
# INFO [2025-06-10 08:58:55] num genes removed taking into account provided gene ordering list: 1280 = 3.49717220840961% removed.
# INFO [2025-06-10 08:58:55] -filtering out cells < 100 or > Inf, removing 0 % of cells
# WARN [2025-06-10 08:58:56] Please use "options(scipen = 100)" before running infercnv if you are using the analysis_mode="subclusters" option or you may encounter an error while the hclust is being generated.
# INFO [2025-06-10 08:59:02] validating infercnv_obj

# %%
# perform infercnv operations to reveal cnv signal
infercnv_obj = infercnv::run(infercnv_obj,
                             cutoff=0.01,  # use 1 for smart-seq, 0.1 for 10x-genomics
                             out_dir="1_vs_4",  # dir is auto-created for storing outputs
                             cluster_by_groups=T,   # cluster
                             denoise=T,
                             plot_steps=F,
                             resume_mode=TRUE,
                             HMM=T,
                             num_threads=5,
                             window_length = 151
                             )
# Out:
# INFO [2025-06-10 08:59:02] ::process_data:Start
# INFO [2025-06-10 08:59:02] Creating output path 1_vs_4
# INFO [2025-06-10 08:59:02] Checking for saved results.
# INFO [2025-06-10 08:59:02]
#
# 	STEP 1: incoming data
#
# INFO [2025-06-10 08:59:41]
#
# 	STEP 02: Removing lowly expressed genes
#
# INFO [2025-06-10 08:59:41] ::above_min_mean_expr_cutoff:Start
# INFO [2025-06-10 08:59:42] Removing 18557 genes from matrix as below mean expr threshold: 0.01
# INFO [2025-06-10 08:59:42] validating infercnv_obj
# INFO [2025-06-10 08:59:42] There are 16764 genes and 7783 cells remaining in the expr matrix.
# INFO [2025-06-10 08:59:48] no genes removed due to min cells/gene filter
# INFO [2025-06-10 09:00:18]
#
# 	STEP 03: normalization by sequencing depth
#
# INFO [2025-06-10 09:00:18] normalizing counts matrix by depth
# INFO [2025-06-10 09:00:22] Computed total sum normalization factor as median libsize: 8174.000000
# INFO [2025-06-10 09:00:56]
#
# 	STEP 04: log transformation of data
#
# ...

# %%
# create the infercnv object
library(infercnv)
infercnv_obj = CreateInfercnvObject(raw_counts_matrix="/content/1_and_95.matrix",
                                    annotations_file="/content/1_vs_95.annotations.tsv",
                                    delim="\t",
                                    gene_order_file="gene_pos_file.txt",
                                    ref_group_names=c("control"))
# Out:
# INFO [2025-06-10 10:06:26] Parsing matrix: /content/1_and_95.matrix
# Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# “number of items read is not a multiple of the number of columns”
# INFO [2025-06-10 10:08:07] Parsing gene order file: gene_pos_file.txt
# INFO [2025-06-10 10:08:07] Parsing cell annotations file: /content/1_vs_95.annotations.tsv
# INFO [2025-06-10 10:08:07] ::order_reduce:Start.
# INFO [2025-06-10 10:08:09] .order_reduce(): expr and order match.
# INFO [2025-06-10 10:08:11] ::process_data:order_reduce:Reduction from positional data, new dimensions (r,c) = 31052,14818 Total=NA Min=NA Max=NA.
# INFO [2025-06-10 10:08:12] num genes removed taking into account provided gene ordering list: 7 = 0.0225428313796213% removed.
# INFO [2025-06-10 10:08:13] -filtering out cells < 100 or > Inf, removing 2.76016 % of cells
# ...

# %%
# perform infercnv operations to reveal cnv signal
infercnv_obj = infercnv::run(infercnv_obj,
                             cutoff=0.01,  # use 1 for smart-seq, 0.1 for 10x-genomics
                             out_dir="1_vs_95",  # dir is auto-created for storing outputs
                             cluster_by_groups=T,   # cluster
                             denoise=T,
                             plot_steps=F,
                             resume_mode=TRUE,
                             HMM=T,
                             num_threads=5,
                             window_length = 151
                             )
# Out:
# INFO [2025-06-10 10:08:26] ::process_data:Start
# INFO [2025-06-10 10:08:26] Creating output path 1_vs_95
# INFO [2025-06-10 10:08:26] Checking for saved results.
# INFO [2025-06-10 10:08:26]
#
# 	STEP 1: incoming data
#
# INFO [2025-06-10 10:09:12]
#
# 	STEP 02: Removing lowly expressed genes
#
# INFO [2025-06-10 10:09:12] ::above_min_mean_expr_cutoff:Start
# INFO [2025-06-10 10:09:13] Removing 18828 genes from matrix as below mean expr threshold: 0.01
# INFO [2025-06-10 10:09:15] validating infercnv_obj
# INFO [2025-06-10 10:09:15] There are 12217 genes and 14407 cells remaining in the expr matrix.
# INFO [2025-06-10 10:09:22] no genes removed due to min cells/gene filter
# INFO [2025-06-10 10:09:53]
#
# 	STEP 03: normalization by sequencing depth
#
# INFO [2025-06-10 10:09:53] normalizing counts matrix by depth
# INFO [2025-06-10 10:09:59] Computed total sum normalization factor as median libsize: 2297.000000
# INFO [2025-06-10 10:10:34]
#
# 	STEP 04: log transformation of data
#
# ...

# %%
# create the infercnv object
library(infercnv)
infercnv_obj = CreateInfercnvObject(raw_counts_matrix="/content/1_and_99.matrix",
                                    annotations_file="/content/1_vs_99.annotations.tsv",
                                    delim="\t",
                                    gene_order_file="gene_pos_file.txt",
                                    ref_group_names=c("control"))
# Out:
# INFO [2025-06-10 11:24:40] Parsing matrix: /content/1_and_99.matrix
# INFO [2025-06-10 11:25:43] Parsing gene order file: gene_pos_file.txt
# INFO [2025-06-10 11:25:43] Parsing cell annotations file: /content/1_vs_99.annotations.tsv
# INFO [2025-06-10 11:25:43] ::order_reduce:Start.
# INFO [2025-06-10 11:25:44] .order_reduce(): expr and order match.
# INFO [2025-06-10 11:25:45] ::process_data:order_reduce:Reduction from positional data, new dimensions (r,c) = 36601,7764 Total=80363403 Min=0 Max=5566.
# INFO [2025-06-10 11:25:46] num genes removed taking into account provided gene ordering list: 1280 = 3.49717220840961% removed.
# INFO [2025-06-10 11:25:46] -filtering out cells < 100 or > Inf, removing 0 % of cells
# WARN [2025-06-10 11:25:49] Please use "options(scipen = 100)" before running infercnv if you are using the analysis_mode="subclusters" option or you may encounter an error while the hclust is being generated.
# INFO [2025-06-10 11:25:54] validating infercnv_obj

# %%
# perform infercnv operations to reveal cnv signal
infercnv_obj = infercnv::run(infercnv_obj,
                             cutoff=0.01,  # use 1 for smart-seq, 0.1 for 10x-genomics
                             out_dir="1_vs_99",  # dir is auto-created for storing outputs
                             cluster_by_groups=T,   # cluster
                             denoise=T,
                             plot_steps=F,
                             resume_mode=TRUE,
                             HMM=T,
                             num_threads=5,
                             window_length = 151
                             )
# Out:
# INFO [2025-06-10 11:25:54] ::process_data:Start
# INFO [2025-06-10 11:25:54] Creating output path 1_vs_99
# INFO [2025-06-10 11:25:54] Checking for saved results.
# INFO [2025-06-10 11:25:54]
#
# 	STEP 1: incoming data
#
# INFO [2025-06-10 11:26:30]
#
# 	STEP 02: Removing lowly expressed genes
#
# INFO [2025-06-10 11:26:30] ::above_min_mean_expr_cutoff:Start
# INFO [2025-06-10 11:26:31] Removing 18720 genes from matrix as below mean expr threshold: 0.01
# INFO [2025-06-10 11:26:32] validating infercnv_obj
# INFO [2025-06-10 11:26:32] There are 16601 genes and 7764 cells remaining in the expr matrix.
# INFO [2025-06-10 11:26:37] no genes removed due to min cells/gene filter
# INFO [2025-06-10 11:27:05]
#
# 	STEP 03: normalization by sequencing depth
#
# INFO [2025-06-10 11:27:05] normalizing counts matrix by depth
# INFO [2025-06-10 11:27:09] Computed total sum normalization factor as median libsize: 7496.500000
# INFO [2025-06-10 11:27:40]
#
# 	STEP 04: log transformation of data
#
# ...

# %%
# create the infercnv object
library(infercnv)
infercnv_obj = CreateInfercnvObject(raw_counts_matrix="/content/all_samples.matrix",
                                    annotations_file="/content/all_samples.annotations.tsv",
                                    delim="\t",
                                    gene_order_file="gene_pos_file.txt",
                                    ref_group_names=c("control"))

# %%
# perform infercnv operations to reveal cnv signal
infercnv_obj = infercnv::run(infercnv_obj,
                             cutoff=0.01,  # use 1 for smart-seq, 0.1 for 10x-genomics
                             out_dir="all_samples",  # dir is auto-created for storing outputs
                             cluster_by_groups=T,   # cluster
                             denoise=T,
                             plot_steps=F,
                             resume_mode=TRUE,
                             HMM=T,
                             num_threads=5,
                             window_length = 151
                             )
